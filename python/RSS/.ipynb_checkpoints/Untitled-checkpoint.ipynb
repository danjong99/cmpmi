# %%
import pandas as pd
from matplotlib import pyplot as pp
import numpy as np
from seaborn import distplot, heatmap, clustermap

# %%
rss =pd.read_table( 'RSS.txt', sep=',', index_col=0)

# %%
rss2 = rss.copy()

# %%
rss2.head()
# Out:
#                               0         1         2         3         4  \
# Tfdp1_extended (133g)  0.313092  0.294346  0.288814  0.283770  0.277295
# Nfyb_extended (47g)    0.326494  0.288173  0.272781  0.271417  0.269899
# Nfyb (28g)             0.318560  0.283999  0.271386  0.270038  0.263681
# E2f2_extended (187g)   0.321376  0.296336  0.285898  0.283055  0.278310
# E2f2 (147g)            0.322111  0.296982  0.284851  0.281556  0.280305
#
#                               5         6         7         8         9  \
# Tfdp1_extended (133g)  0.256115  0.256448  0.245904  0.239797  0.243486
# Nfyb_extended (47g)    0.256496  0.240220  0.234345  0.251575  0.281652
# Nfyb (28g)             0.260368  0.240130  0.235122  0.250420  0.298454
# E2f2_extended (187g)   0.255527  0.246751  0.241177  0.241961  0.246979
# E2f2 (147g)            0.253480  0.246256  0.239915  0.243490  0.248338
#
#                              10        11        12
# Tfdp1_extended (133g)  0.206791  0.187775  0.175315
# Nfyb_extended (47g)    0.206976  0.186298  0.176107
# Nfyb (28g)             0.203452  0.185997  0.173749
# E2f2_extended (187g)   0.208477  0.187185  0.176356
# E2f2 (147g)            0.208094  0.186927  0.175754

# %%
for i,v in rss.iteritems() :
    rss2[i] = (v - np.mean(v))/ np.std(v)
